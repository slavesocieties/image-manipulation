# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
from skimage.filters import threshold_otsu

# %%
import skimage.data as data
import skimage.segmentation as seg
import skimage.filters as filters
import skimage.draw as draw
import skimage.color as color

# %%
image = io.imread("1004.JPG")
plt.imshow(image);

# %%
def image_show(image, nrows=1, ncols=1, cmap='gray'):
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(14, 14))
    ax.imshow(image, cmap='gray')
    ax.axis('off')
    return fig, ax

# %%
image_show(image)
# Out:
# (<Figure size 1008x1008 with 1 Axes>, <AxesSubplot:>)

# %%
fig, ax = plt.subplots(1, 1)
ax.hist(image.ravel(), bins=32, range=[0, 256])
ax.set_xlim(0, 256);

# %%
gray_image = color.rgb2gray(image)

image_show(gray_image)
# Out:
# (<Figure size 1008x1008 with 1 Axes>, <AxesSubplot:>)

# %%
fig, ax = plt.subplots(1, 1)
ax.hist(image.ravel(), bins=32, range=[0, 256])
ax.set_xlim(0, 256);

# %%
image_segmented = gray_image > .55
image_show(image_segmented);

# %%
thresh = threshold_otsu(gray_image)

# %%
thresh
# Out:
# 0.34756998697916663

# %%
from skimage.filters import try_all_threshold

img = gray_image

fig, ax = try_all_threshold(img, figsize=(10,8), verbose=False)
plt.show()
# Out:
# c:\users\genkindn\appdata\local\programs\python\python39\lib\site-packages\skimage\filters\thresholding.py:409: RuntimeWarning: divide by zero encountered in log
#   crit = np.log(((P1_sq[:-1] * P2_sq[1:]) ** -1) *
